# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
res = classifier("I've been waiting for a HuggingFace course my whole life.")
res
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9598049521446228}]

# %%
generator = pipeline("text-generation", model="distilgpt2")
res2 = generator("In this course I will teach you how to use the", max_length=30, num_return_sequences=2, truncation=True)
print(res2)
# Out:
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'In this course I will teach you how to use the Windows Server 2008.1.1.1 to control your servers, as well as installing a new set of custom Windows Server 2008.1.1.1 and running Windows Server 2008.1.1.1 on your computer, and then using the following script:\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNow, this may be a little confusing, but a lot of my friends and I have been using Windows Server 2008.1.1.1 for years now, and I am happy with the results of this guide. I have no problem installing it on your computer, but I think this guide will be useful for you if you have a problem with Windows Server 2008.1.1.1.1.1 and want to learn all the details for the current version of the virtual machine.\nIn the meantime, I am happy to share your thoughts on the new Windows Server 2008.1.1.1 installation and how you can get started using the new Windows Server 2008.1.1.1.1, and how to use the new Windows Server 2008.1.1.1.1 install and install all the details for the current version of the virtual machine.\nIn the'}, {'generated_text': 'In this course I will teach you how to use the free software at the University of Wisconsin, and how to do this with other UW students.\n\n\nThis course will also teach you how to use the free software at the University of Wisconsin, and how to do this with other UW students.\nThis course will also teach you how to use the free software at the University of Wisconsin, and how to do this with other UW students.\nThis course will also teach you how to use the free software at the University of Wisconsin, and how to do this with other UW students.\nThis course will also teach you how to use the free software at the University of Wisconsin, and how to do this with other UW students.\nThis course will also teach you how to use the free software at the University of Wisconsin, and how to do this with other UW students.\nThis course will also teach you how to use the free software at the University of Wisconsin, and how to do this with other UW students.'}]

# %%
classifier = pipeline("zero-shot-classification")
res = classifier(
    "This is a test",
    candidate_labels=["food", "sports", "travel"],
    multi_label=True,
)
print(res)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]

# %%
from transformers
